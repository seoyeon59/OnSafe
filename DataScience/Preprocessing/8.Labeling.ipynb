# %%
# 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 기본 라이브러리 할당
import pandas as pd

# %%
df_path = "/content/drive/MyDrive/OnSafe/make_feature.csv"

df = pd.read_csv(df_path)

# 정상 : 0 / 낙상 : 1 로 지정 : 데이터셋에 따라 코드 변동 가능성 존재
df['Label'] = df['video'].apply(lambda x: 0 if 'ADL' in x else 1)

# 파일 생성
df.to_csv("/content/drive/MyDrive/OnSafe/modeling.csv", index=False)
